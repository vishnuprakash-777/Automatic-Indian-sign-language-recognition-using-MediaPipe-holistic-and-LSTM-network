# %%
import cv2
import os
import numpy as np

def augment_video(input_video_path, augmentations):
    """
    Augments a video by applying transformations and saves them in the same folder.

    Parameters:
    - input_video_path (str): Path to the input video.
    - augmentations (list): List of augmentation functions to apply.

    Returns:
    - None
    """
    # Open the input video
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {input_video_path}")
        return

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for output videos

    # Get video base name and directory
    video_name = os.path.basename(input_video_path)
    base_name, ext = os.path.splitext(video_name)
    video_dir = os.path.dirname(input_video_path)

    # Apply each augmentation
    for augment in augmentations:
        augment_name = augment.__name__
        output_file = os.path.join(video_dir, f"{base_name}_{augment_name}{ext}")
        out = cv2.VideoWriter(output_file, fourcc, fps, (frame_width, frame_height))

        # Reset video capture
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Apply augmentation
            augmented_frame = augment(frame)
            out.write(augmented_frame)

        out.release()
        print(f"Augmented video saved at: {output_file}")

    cap.release()

# Define augmentation functions
def rotate_left(frame, angle=10):
    """Rotate the frame 10° to the left."""
    h, w = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, -angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h))

def rotate_right(frame, angle=10):
    """Rotate the frame 10° to the right."""
    h, w = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h))

def add_blur(frame, kernel_size=(5, 5)):
    """Add Gaussian blur to the frame."""
    return cv2.GaussianBlur(frame, kernel_size, 0)

def increase_brightness(frame, value=30):
    """Increase the brightness of the frame."""
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)  # Convert to HSV
    h, s, v = cv2.split(hsv)
    v = cv2.add(v, value)  # Increase brightness
    v = np.clip(v, 0, 255)  # Ensure pixel values are valid
    hsv = cv2.merge((h, s, v))
    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def adjust_contrast(frame, alpha=1.5, beta=0):
    """
    Adjust the contrast of the frame.
    - `alpha` controls contrast (1.0 keeps original, >1 increases contrast).
    - `beta` controls brightness (0 keeps original, >0 increases brightness).
    """
    return cv2.convertScaleAbs(frame, alpha=alpha, beta=beta)

def add_noise(frame, mean=0, sigma=25):
    """Add Gaussian noise to the frame."""
    row, col, ch = frame.shape
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    noisy_frame = np.uint8(np.clip(frame + gauss, 0, 255))
    return noisy_frame

# Process all videos in the given folder
def process_folder(folder_path, augmentations):
    """
    Process all `.MOV` videos in the folder for augmentation.

    Parameters:
    - folder_path (str): Path to the folder containing videos.
    - augmentations (list): List of augmentation functions to apply.

    Returns:
    - None
    """
    if not os.path.exists(folder_path):
        print(f"Folder does not exist: {folder_path}")
        return

    for video_file in os.listdir(folder_path):
        video_path = os.path.join(folder_path, video_file)

        # Check if the file is a .MOV video
        if os.path.isfile(video_path) and video_file.endswith('.MOV'):
            print(f"Processing video: {video_file}")
            augment_video(video_path, augmentations)

# Example usage
if __name__ == "__main__":
    load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat"  # Replace with the path to your 'load' folder
    augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

    process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5156.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5156_add_noise.MOV
# Processing video: MVI_5155.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5155_add_noise.MOV
# Processing video: MVI_3691.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3691_add_noise.MOV
# Processing video: MVI_3690.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3690_add_noise.MOV
# Processing video: MVI_5008.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5008_add_noise.MOV
# Processing video: MVI_5154.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5154_add_noise.MOV
# Processing video: MVI_3985.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3985_add_noise.MOV
# Processing video: MVI_3984.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3984_add_noise.MOV
# Processing video: MVI_3986.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3986_add_noise.MOV
# Processing video: MVI_4197.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4197_add_noise.MOV
# Processing video: MVI_3835.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3835_add_noise.MOV
# Processing video: MVI_3837.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3837_add_noise.MOV
# Processing video: MVI_3836.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3836_add_noise.MOV
# Processing video: MVI_3688.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_3688_add_noise.MOV
# Processing video: MVI_4865.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4865_add_noise.MOV
# Processing video: MVI_5006.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5006_add_noise.MOV
# Processing video: MVI_4867.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4867_add_noise.MOV
# Processing video: MVI_4866.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_4866_add_noise.MOV
# Processing video: MVI_5007.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/37. Hat/MVI_5007_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3697.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_add_noise.MOV
# Processing video: MVI_4199.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_add_noise.MOV
# Processing video: MVI_3991.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_add_noise.MOV
# Processing video: MVI_3990.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_add_noise.MOV
# Processing video: MVI_3992.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_add_noise.MOV
# Processing video: MVI_4871.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_add_noise.MOV
# Processing video: MVI_5012.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_add_noise.MOV
# Processing video: MVI_4873.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_add_noise.MOV
# Processing video: MVI_4872.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_add_noise.MOV
# Processing video: MVI_5013.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_add_noise.MOV
# Processing video: MVI_3843.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_add_noise.MOV
# Processing video: MVI_3842.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_add_noise.MOV
# Processing video: MVI_5162.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_add_noise.MOV
# Processing video: MVI_5160.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_add_noise.MOV
# Processing video: MVI_5014.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_add_noise.MOV
# Processing video: MVI_3698.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_add_noise.MOV
# Processing video: MVI_3841.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_add_noise.MOV
# Processing video: MVI_5161.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3694.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_add_noise.MOV
# Processing video: MVI_3696.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_add_noise.MOV
# Processing video: MVI_3693.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_add_noise.MOV
# Processing video: MVI_5157.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_add_noise.MOV
# Processing video: MVI_5009.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_add_noise.MOV
# Processing video: MVI_4868.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_add_noise.MOV
# Processing video: MVI_4869.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_add_noise.MOV
# Processing video: MVI_4198.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_add_noise.MOV
# Processing video: MVI_3838.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_add_noise.MOV
# Processing video: MVI_3839.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_add_noise.MOV
# Processing video: MVI_3989.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_add_noise.MOV
# Processing video: MVI_3988.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_add_noise.MOV
# Processing video: MVI_3987.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_add_noise.MOV
# Processing video: MVI_5159.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_add_noise.MOV
# Processing video: MVI_5011.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_add_noise.MOV
# Processing video: MVI_4870.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_add_noise.MOV
# Processing video: MVI_5010.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_add_noise.MOV
# Processing video: MVI_5158.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_add_noise.MOV
# Processing video: MVI_3840.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3998.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3998_add_noise.MOV
# Processing video: MVI_4200.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4200_add_noise.MOV
# Processing video: MVI_3997.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3997_add_noise.MOV
# Processing video: MVI_3996.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3996_add_noise.MOV
# Processing video: MVI_5165.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5165_add_noise.MOV
# Processing video: MVI_3845.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3845_add_noise.MOV
# Processing video: MVI_3844.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3844_add_noise.MOV
# Processing video: MVI_5164.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5164_add_noise.MOV
# Processing video: MVI_3846.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3846_add_noise.MOV
# Processing video: MVI_3700.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3700_add_noise.MOV
# Processing video: MVI_5163.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5163_add_noise.MOV
# Processing video: MVI_5017.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5017_add_noise.MOV
# Processing video: MVI_4876.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4876_add_noise.MOV
# Processing video: MVI_5016.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5016_add_noise.MOV
# Processing video: MVI_4875.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4875_add_noise.MOV
# Processing video: MVI_4874.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_4874_add_noise.MOV
# Processing video: MVI_3699.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_3699_add_noise.MOV
# Processing video: MVI_5015.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/40. Skirt/MVI_5015_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5018.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5018_add_noise.MOV
# Processing video: MVI_4879.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4879_add_noise.MOV
# Processing video: MVI_5019.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5019_add_noise.MOV
# Processing video: MVI_4880.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4880_add_noise.MOV
# Processing video: MVI_3849.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3849_add_noise.MOV
# Processing video: MVI_3848.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3848_add_noise.MOV
# Processing video: MVI_5020.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5020_add_noise.MOV
# Processing video: MVI_5168.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5168_add_noise.MOV
# Processing video: MVI_3999.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3999_add_noise.MOV
# Processing video: MVI_4001.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4001_add_noise.MOV
# Processing video: MVI_4000.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4000_add_noise.MOV
# Processing video: MVI_4201.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4201_add_noise.MOV
# Processing video: MVI_3702.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3702_add_noise.MOV
# Processing video: MVI_3703.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3703_add_noise.MOV
# Processing video: MVI_3701.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3701_add_noise.MOV
# Processing video: MVI_5166.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5166_add_noise.MOV
# Processing video: MVI_3847.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_3847_add_noise.MOV
# Processing video: MVI_5167.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_5167_add_noise.MOV
# Processing video: MVI_4877.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/41. Shirt/MVI_4877_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5022.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_add_noise.MOV
# Processing video: MVI_4881.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_add_noise.MOV
# Processing video: MVI_5023.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_add_noise.MOV
# Processing video: MVI_5169.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_add_noise.MOV
# Processing video: MVI_5021.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_add_noise.MOV
# Processing video: MVI_4883.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_add_noise.MOV
# Processing video: MVI_4882.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_add_noise.MOV
# Processing video: MVI_4004.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_add_noise.MOV
# Processing video: MVI_4202.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_add_noise.MOV
# Processing video: MVI_4002.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_add_noise.MOV
# Processing video: MVI_4003.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_add_noise.MOV
# Processing video: MVI_5171.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_add_noise.MOV
# Processing video: MVI_3851.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_add_noise.MOV
# Processing video: MVI_3850.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_add_noise.MOV
# Processing video: MVI_5170.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_add_noise.MOV
# Processing video: MVI_3852.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_add_noise.MOV
# Processing video: MVI_3704.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_add_noise.MOV
# Processing video: MVI_3705.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_add_noise.MOV
# Processing video: MVI_3706.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5024.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5024_add_noise.MOV
# Processing video: MVI_4886.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4886_add_noise.MOV
# Processing video: MVI_5025.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5025_add_noise.MOV
# Processing video: MVI_3708.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3708_add_noise.MOV
# Processing video: MVI_4885.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4885_add_noise.MOV
# Processing video: MVI_4884.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4884_add_noise.MOV
# Processing video: MVI_5026.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5026_add_noise.MOV
# Processing video: MVI_3709.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3709_add_noise.MOV
# Processing video: MVI_4007.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4007_add_noise.MOV
# Processing video: MVI_4006.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4006_add_noise.MOV
# Processing video: MVI_4005.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4005_add_noise.MOV
# Processing video: MVI_4203.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_4203_add_noise.MOV
# Processing video: MVI_5172.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5172_add_noise.MOV
# Processing video: MVI_3853.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3853_add_noise.MOV
# Processing video: MVI_5173.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5173_add_noise.MOV
# Processing video: MVI_3707.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3707_add_noise.MOV
# Processing video: MVI_5174.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_5174_add_noise.MOV
# Processing video: MVI_3854.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3854_add_noise.MOV
# Processing video: MVI_3855.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/43. Pant/MVI_3855_add_noise.MOV

# %%
import cv2
import os
import numpy as np

def augment_video(input_video_path, augmentations):
    """
    Augments a video by applying transformations and saves them in the same folder.

    Parameters:
    - input_video_path (str): Path to the input video.
    - augmentations (list): List of augmentation functions to apply.

    Returns:
    - None
    """
    # Open the input video
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {input_video_path}")
        return

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for output videos

    # Get video base name and directory
    video_name = os.path.basename(input_video_path)
    base_name, ext = os.path.splitext(video_name)
    video_dir = os.path.dirname(input_video_path)

    # Apply each augmentation
    for augment in augmentations:
        augment_name = augment.__name__
        output_file = os.path.join(video_dir, f"{base_name}_{augment_name}{ext}")
        out = cv2.VideoWriter(output_file, fourcc, fps, (frame_width, frame_height))

        # Reset video capture
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Apply augmentation
            augmented_frame = augment(frame)
            out.write(augmented_frame)

        out.release()
        print(f"Augmented video saved at: {output_file}")

    cap.release()

# Define augmentation functions
def rotate_left(frame, angle=10):
    """Rotate the frame 10° to the left."""
    h, w = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, -angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h))

def rotate_right(frame, angle=10):
    """Rotate the frame 10° to the right."""
    h, w = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h))

def add_blur(frame, kernel_size=(5, 5)):
    """Add Gaussian blur to the frame."""
    return cv2.GaussianBlur(frame, kernel_size, 0)

def increase_brightness(frame, value=30):
    """Increase the brightness of the frame."""
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)  # Convert to HSV
    h, s, v = cv2.split(hsv)
    v = cv2.add(v, value)  # Increase brightness
    v = np.clip(v, 0, 255)  # Ensure pixel values are valid
    hsv = cv2.merge((h, s, v))
    return cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

def adjust_contrast(frame, alpha=1.5, beta=0):
    """
    Adjust the contrast of the frame.
    - `alpha` controls contrast (1.0 keeps original, >1 increases contrast).
    - `beta` controls brightness (0 keeps original, >0 increases brightness).
    """
    return cv2.convertScaleAbs(frame, alpha=alpha, beta=beta)

def add_noise(frame, mean=0, sigma=25):
    """Add Gaussian noise to the frame."""
    row, col, ch = frame.shape
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    noisy_frame = np.uint8(np.clip(frame + gauss, 0, 255))
    return noisy_frame

# Process all videos in the given folder
def process_folder(folder_path, augmentations):
    """
    Process all `.MOV` videos in the folder for augmentation.

    Parameters:
    - folder_path (str): Path to the folder containing videos.
    - augmentations (list): List of augmentation functions to apply.

    Returns:
    - None
    """
    if not os.path.exists(folder_path):
        print(f"Folder does not exist: {folder_path}")
        return

    for video_file in os.listdir(folder_path):
        video_path = os.path.join(folder_path, video_file)

        # Check if the file is a .MOV video
        if os.path.isfile(video_path) and video_file.endswith('.MOV'):
            print(f"Processing video: {video_file}")
            augment_video(video_path, augmentations)

# Example usage
if __name__ == "__main__":
    load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes"  # Replace with the path to your 'load' folder
    augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

    process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5030.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5030_add_noise.MOV
# Processing video: MVI_3858.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3858_add_noise.MOV
# Processing video: MVI_4887.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4887_add_noise.MOV
# Processing video: MVI_4204.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4204_add_noise.MOV
# Processing video: MVI_4010.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4010_add_noise.MOV
# Processing video: MVI_4008.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4008_add_noise.MOV
# Processing video: MVI_4009.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4009_add_noise.MOV
# Processing video: MVI_3710.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3710_add_noise.MOV
# Processing video: MVI_5177.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5177_add_noise.MOV
# Processing video: MVI_4889.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4889_add_noise.MOV
# Processing video: MVI_3857.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3857_add_noise.MOV
# Processing video: MVI_3856.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3856_add_noise.MOV
# Processing video: MVI_4888.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_4888_add_noise.MOV
# Processing video: MVI_5176.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5176_add_noise.MOV
# Processing video: MVI_3711.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3711_add_noise.MOV
# Processing video: MVI_5028.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5028_add_noise.MOV
# Processing video: MVI_5029.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5029_add_noise.MOV
# Processing video: MVI_5175.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_5175_add_noise.MOV
# Processing video: MVI_3712.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/44. Shoes/MVI_3712_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5022.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5022_add_noise.MOV
# Processing video: MVI_4881.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4881_add_noise.MOV
# Processing video: MVI_5023.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5023_add_noise.MOV
# Processing video: MVI_5169.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5169_add_noise.MOV
# Processing video: MVI_5021.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5021_add_noise.MOV
# Processing video: MVI_4883.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4883_add_noise.MOV
# Processing video: MVI_4882.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4882_add_noise.MOV
# Processing video: MVI_4004.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4004_add_noise.MOV
# Processing video: MVI_4202.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4202_add_noise.MOV
# Processing video: MVI_4002.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4002_add_noise.MOV
# Processing video: MVI_4003.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_4003_add_noise.MOV
# Processing video: MVI_5171.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5171_add_noise.MOV
# Processing video: MVI_3851.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3851_add_noise.MOV
# Processing video: MVI_3850.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3850_add_noise.MOV
# Processing video: MVI_5170.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_5170_add_noise.MOV
# Processing video: MVI_3852.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3852_add_noise.MOV
# Processing video: MVI_3704.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3704_add_noise.MOV
# Processing video: MVI_3705.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3705_add_noise.MOV
# Processing video: MVI_3706.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/42. T-Shirt/MVI_3706_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_5178.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5178_add_noise.MOV
# Processing video: MVI_4892.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4892_add_noise.MOV
# Processing video: MVI_3859.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3859_add_noise.MOV
# Processing video: MVI_5031.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5031_add_noise.MOV
# Processing video: MVI_5179.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5179_add_noise.MOV
# Processing video: MVI_5033.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5033_add_noise.MOV
# Processing video: MVI_4891.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4891_add_noise.MOV
# Processing video: MVI_4890.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4890_add_noise.MOV
# Processing video: MVI_5032.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5032_add_noise.MOV
# Processing video: MVI_3862.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3862_add_noise.MOV
# Processing video: MVI_5180.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_5180_add_noise.MOV
# Processing video: MVI_3861.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3861_add_noise.MOV
# Processing video: MVI_4013.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4013_add_noise.MOV
# Processing video: MVI_4205.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4205_add_noise.MOV
# Processing video: MVI_4012.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4012_add_noise.MOV
# Processing video: MVI_4011.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_4011_add_noise.MOV
# Processing video: MVI_3715.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3715_add_noise.MOV
# Processing video: MVI_3714.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3714_add_noise.MOV
# Processing video: MVI_3713.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/45. Pocket/MVI_3713_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3864.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3864_add_noise.MOV
# Processing video: MVI_3865.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3865_add_noise.MOV
# Processing video: MVI_5181.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5181_add_noise.MOV
# Processing video: MVI_5036.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5036_add_noise.MOV
# Processing video: MVI_4894.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4894_add_noise.MOV
# Processing video: MVI_3863.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3863_add_noise.MOV
# Processing video: MVI_4895.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4895_add_noise.MOV
# Processing video: MVI_3718.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3718_add_noise.MOV
# Processing video: MVI_5182.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5182_add_noise.MOV
# Processing video: MVI_5035.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5035_add_noise.MOV
# Processing video: MVI_4896.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4896_add_noise.MOV
# Processing video: MVI_5034.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5034_add_noise.MOV
# Processing video: MVI_5183.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_5183_add_noise.MOV
# Processing video: MVI_4206.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4206_add_noise.MOV
# Processing video: MVI_4015.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4015_add_noise.MOV
# Processing video: MVI_4014.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4014_add_noise.MOV
# Processing video: MVI_4016.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_4016_add_noise.MOV
# Processing video: MVI_3716.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3716_add_noise.MOV
# Processing video: MVI_3717.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes/46. Clothing/MVI_3717_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3694.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3694_add_noise.MOV
# Processing video: MVI_3696.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3696_add_noise.MOV
# Processing video: MVI_3693.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3693_add_noise.MOV
# Processing video: MVI_5157.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5157_add_noise.MOV
# Processing video: MVI_5009.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5009_add_noise.MOV
# Processing video: MVI_4868.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4868_add_noise.MOV
# Processing video: MVI_4869.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4869_add_noise.MOV
# Processing video: MVI_4198.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4198_add_noise.MOV
# Processing video: MVI_3838.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3838_add_noise.MOV
# Processing video: MVI_3839.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3839_add_noise.MOV
# Processing video: MVI_3989.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3989_add_noise.MOV
# Processing video: MVI_3988.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3988_add_noise.MOV
# Processing video: MVI_3987.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3987_add_noise.MOV
# Processing video: MVI_5159.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5159_add_noise.MOV
# Processing video: MVI_5011.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5011_add_noise.MOV
# Processing video: MVI_4870.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_4870_add_noise.MOV
# Processing video: MVI_5010.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5010_add_noise.MOV
# Processing video: MVI_5158.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_5158_add_noise.MOV
# Processing video: MVI_3840.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/38. Dress/MVI_3840_add_noise.MOV

# %%
load_folder = "/Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit"  # Replace with the path to your 'load' folder
augmentations = [rotate_left, rotate_right, add_blur, increase_brightness,adjust_contrast,add_noise]

process_folder(load_folder, augmentations)
# Out:
# Processing video: MVI_3697.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3697_add_noise.MOV
# Processing video: MVI_4199.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4199_add_noise.MOV
# Processing video: MVI_3991.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3991_add_noise.MOV
# Processing video: MVI_3990.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3990_add_noise.MOV
# Processing video: MVI_3992.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3992_add_noise.MOV
# Processing video: MVI_4871.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4871_add_noise.MOV
# Processing video: MVI_5012.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5012_add_noise.MOV
# Processing video: MVI_4873.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4873_add_noise.MOV
# Processing video: MVI_4872.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_4872_add_noise.MOV
# Processing video: MVI_5013.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5013_add_noise.MOV
# Processing video: MVI_3843.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3843_add_noise.MOV
# Processing video: MVI_3842.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3842_add_noise.MOV
# Processing video: MVI_5162.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5162_add_noise.MOV
# Processing video: MVI_5160.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5160_add_noise.MOV
# Processing video: MVI_5014.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5014_add_noise.MOV
# Processing video: MVI_3698.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3698_add_noise.MOV
# Processing video: MVI_3841.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_3841_add_noise.MOV
# Processing video: MVI_5161.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_rotate_left.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_rotate_right.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_add_blur.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_increase_brightness.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_adjust_contrast.MOV
# Augmented video saved at: /Users/vishnuprakash/Documents/mini_project/Clothes 2/39. Suit/MVI_5161_add_noise.MOV
