# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split

# Function to load keypoints and labels
def load_keypoints_and_labels(keypoints_dir):
    """
    Load keypoints and labels from CSV files in the specified directory.

    Parameters:
    - keypoints_dir (str): Directory containing class folders with CSV files.

    Returns:
    - keypoints (list of numpy arrays): List of sequences with shape (frames, features).
    - labels (list of str): Corresponding labels for each sequence.
    """
    keypoints = []
    labels = []

    for class_folder in os.listdir(keypoints_dir):
        class_path = os.path.join(keypoints_dir, class_folder)
        if os.path.isdir(class_path):
            for file in os.listdir(class_path):
                if file.endswith(".csv"):
                    file_path = os.path.join(class_path, file)
                    data = np.loadtxt(file_path, delimiter=",")

                    # Append the data and label
                    keypoints.append(data)
                    labels.append(class_folder)

    return keypoints, labels

# Function to pad sequences to the same length
def pad_sequences(data, max_frames, max_features):
    """
    Pad sequences to have a consistent frame count with zeros.

    Parameters:
    - data (list of numpy arrays): List of sequences (keypoints).
    - max_frames (int): Maximum frame count.
    - max_features (int): Number of features per frame.

    Returns:
    - padded_data (numpy array): Padded sequences.
    """
    padded_data = []
    for seq in data:
        if seq.shape[0] < max_frames:
            padding = np.zeros((max_frames - seq.shape[0], max_features))
            padded_seq = np.vstack((seq, padding))
        else:
            padded_seq = seq[:max_frames]  # Truncate if necessary
        padded_data.append(padded_seq)

    return np.array(padded_data)

# Main script
if __name__ == "__main__":
    # Path to keypoints directory
    keypoints_dir = "/content/drive/MyDrive/keypoints"  # Replace with your directory path

    # Load keypoints and labels
    keypoints, labels = load_keypoints_and_labels(keypoints_dir)
    print(f"Loaded {len(keypoints)} sequences with corresponding labels.")

    # Determine maximum frames and features
    max_frames = max(seq.shape[0] for seq in keypoints)
    max_features = keypoints[0].shape[1]
    print(f"Maximum frames: {max_frames}, Features per frame: {max_features}")

    # Pad sequences to have consistent lengths
    keypoints_padded = pad_sequences(keypoints, max_frames, max_features)
    print(f"Padded sequences shape: {keypoints_padded.shape}")

    # Encode labels
    label_encoder = LabelEncoder()
    labels_encoded = label_encoder.fit_transform(labels)
    labels_categorical = to_categorical(labels_encoded)
    print(f"Number of classes: {len(label_encoder.classes_)}")

    # Split data into train, validation, and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        keypoints_padded, labels_categorical, test_size=0.2, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.2, random_state=42
    )
# Out:
# Loaded 1316 sequences with corresponding labels.
# Maximum frames: 116, Features per frame: 1662
# Padded sequences shape: (1316, 116, 1662)
# Number of classes: 10

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(max_frames, max_features)),
    Dropout(0.2),
    LSTM(32),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 116, 64)             │         442,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 116, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 454,858 (1.74 MB)
#  Trainable params: 454,858 (1.74 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,  # Set a higher number of epochs but stop early if necessary
    batch_size=16,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.3514 - loss: 1.5586 - val_accuracy: 0.3223 - val_loss: 1.5245
# Epoch 2/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 14s 273ms/step - accuracy: 0.3715 - loss: 1.4545 - val_accuracy: 0.3223 - val_loss: 1.5108
# Epoch 3/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.3529 - loss: 1.4667 - val_accuracy: 0.3365 - val_loss: 1.3910
# Epoch 4/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 20s 261ms/step - accuracy: 0.3891 - loss: 1.3723 - val_accuracy: 0.3744 - val_loss: 1.3521
# Epoch 5/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 236ms/step - accuracy: 0.4206 - loss: 1.3361 - val_accuracy: 0.3649 - val_loss: 1.4646
# Epoch 6/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 22s 259ms/step - accuracy: 0.3724 - loss: 1.3834 - val_accuracy: 0.3270 - val_loss: 1.3734
# Epoch 7/20
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 236ms/step - accuracy: 0.3732 - loss: 1.5154 - val_accuracy: 0.3460 - val_loss: 1.4493

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.4624 - loss: 1.3320
# Test Accuracy: 44.70%

# %%
model = Sequential([
        LSTM(128, return_sequences=True, input_shape=(max_frames, max_features)),
        Dropout(0.2),
        LSTM(64),
        Dense(32, activation='relu'),
        Dense(len(label_encoder.classes_), activation='softmax')
    ])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 116, 128)            │         916,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 116, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 968,810 (3.70 MB)
#  Trainable params: 968,810 (3.70 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
 history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=20,
        batch_size=32
    )
# Out:
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 23s 690ms/step - accuracy: 0.1028 - loss: 2.2743 - val_accuracy: 0.1422 - val_loss: 2.1497
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 699ms/step - accuracy: 0.1679 - loss: 2.1668 - val_accuracy: 0.1801 - val_loss: 2.0742
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 652ms/step - accuracy: 0.2220 - loss: 2.0543 - val_accuracy: 0.2180 - val_loss: 1.9958
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 645ms/step - accuracy: 0.2321 - loss: 2.0362 - val_accuracy: 0.2133 - val_loss: 2.0357
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 656ms/step - accuracy: 0.2034 - loss: 2.0102 - val_accuracy: 0.2133 - val_loss: 1.9105
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 635ms/step - accuracy: 0.2401 - loss: 1.9236 - val_accuracy: 0.2417 - val_loss: 1.8629
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 635ms/step - accuracy: 0.2021 - loss: 1.8945 - val_accuracy: 0.2322 - val_loss: 1.8101
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 659ms/step - accuracy: 0.2457 - loss: 1.8375 - val_accuracy: 0.2227 - val_loss: 1.7752
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 636ms/step - accuracy: 0.2624 - loss: 1.7325 - val_accuracy: 0.2607 - val_loss: 1.6978
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 636ms/step - accuracy: 0.3368 - loss: 1.6573 - val_accuracy: 0.2749 - val_loss: 1.6174
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 655ms/step - accuracy: 0.2462 - loss: 1.7807 - val_accuracy: 0.1896 - val_loss: 1.8520
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 642ms/step - accuracy: 0.2678 - loss: 1.7390 - val_accuracy: 0.2844 - val_loss: 1.6379
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 638ms/step - accuracy: 0.3233 - loss: 1.5984 - val_accuracy: 0.2844 - val_loss: 1.5688
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 22s 668ms/step - accuracy: 0.2763 - loss: 1.5782 - val_accuracy: 0.3175 - val_loss: 1.5520
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 641ms/step - accuracy: 0.3044 - loss: 1.5684 - val_accuracy: 0.2938 - val_loss: 1.6061
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 641ms/step - accuracy: 0.3331 - loss: 1.5986 - val_accuracy: 0.3270 - val_loss: 1.5076
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 669ms/step - accuracy: 0.3219 - loss: 1.5281 - val_accuracy: 0.3081 - val_loss: 1.5377
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 628ms/step - accuracy: 0.3661 - loss: 1.4664 - val_accuracy: 0.3555 - val_loss: 1.4589
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 633ms/step - accuracy: 0.3282 - loss: 1.4423 - val_accuracy: 0.2986 - val_loss: 1.5495
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 624ms/step - accuracy: 0.3584 - loss: 1.4460 - val_accuracy: 0.2986 - val_loss: 1.5768

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.3175 - loss: 1.5435
# Test Accuracy: 30.68%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import os

class_names = sorted(os.listdir(keypoints_dir))
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to one-hot encoded format if necessary
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Print classification report
print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 545ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Clothing       0.22      0.77      0.34        22
#        Dress       1.00      0.04      0.08        24
#          Hat       1.00      0.14      0.24        29
#         Pant       0.34      0.96      0.50        27
#       Pocket       0.20      0.04      0.07        23
#        Shirt       0.42      0.54      0.47        26
#        Shoes       0.40      0.15      0.22        26
#        Skirt       0.08      0.10      0.09        30
#         Suit       1.00      0.03      0.06        30
#      T-Shirt       0.53      0.37      0.43        27
#
#     accuracy                           0.31       264
#    macro avg       0.52      0.32      0.25       264
# weighted avg       0.53      0.31      0.25       264

# %%
from tensorflow.keras.layers import Masking, LSTM, Dense
model = Sequential([
        Masking(mask_value=0.0, input_shape=(max_frames, max_features)),
        LSTM(64, activation='tanh', return_sequences=False),  # LSTM with 64 units
        Dense(64, activation='tanh'),  # Fully connected layer
        Dense(10, activation='softmax')  # Output layer
    ])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/masking.py:47: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
 model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

# %%
 history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=32
    )
# Out:
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 417ms/step - accuracy: 0.7641 - loss: 0.5641 - val_accuracy: 0.6635 - val_loss: 0.7928
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 274ms/step - accuracy: 0.7824 - loss: 0.5597 - val_accuracy: 0.7251 - val_loss: 0.7478
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.8101 - loss: 0.5389 - val_accuracy: 0.7251 - val_loss: 0.7814
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 382ms/step - accuracy: 0.7791 - loss: 0.6002 - val_accuracy: 0.6777 - val_loss: 0.8035
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 351ms/step - accuracy: 0.7689 - loss: 0.5833 - val_accuracy: 0.6635 - val_loss: 0.8153
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.7527 - loss: 0.5929 - val_accuracy: 0.7156 - val_loss: 0.8215
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.7852 - loss: 0.6403 - val_accuracy: 0.7062 - val_loss: 0.7535
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 354ms/step - accuracy: 0.7771 - loss: 0.5768 - val_accuracy: 0.6161 - val_loss: 1.0230
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.7639 - loss: 0.6156 - val_accuracy: 0.7393 - val_loss: 0.6724
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.8024 - loss: 0.5230 - val_accuracy: 0.7536 - val_loss: 0.6833
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 0.8048 - loss: 0.5040 - val_accuracy: 0.7393 - val_loss: 0.6618
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.7752 - loss: 0.5576 - val_accuracy: 0.7109 - val_loss: 0.7496
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 306ms/step - accuracy: 0.7879 - loss: 0.5239 - val_accuracy: 0.7204 - val_loss: 0.7416
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 377ms/step - accuracy: 0.8002 - loss: 0.4937 - val_accuracy: 0.7393 - val_loss: 0.7246
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.7858 - loss: 0.5335 - val_accuracy: 0.6730 - val_loss: 0.7862
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 294ms/step - accuracy: 0.7970 - loss: 0.5196 - val_accuracy: 0.7299 - val_loss: 0.7561
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - accuracy: 0.7987 - loss: 0.5016 - val_accuracy: 0.7773 - val_loss: 0.6131
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 280ms/step - accuracy: 0.8483 - loss: 0.4332 - val_accuracy: 0.7346 - val_loss: 0.6421
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.7521 - loss: 0.7040 - val_accuracy: 0.7346 - val_loss: 0.6940
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.7303 - loss: 0.6164 - val_accuracy: 0.7678 - val_loss: 0.6642
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.8174 - loss: 0.4638 - val_accuracy: 0.7204 - val_loss: 0.6979
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 374ms/step - accuracy: 0.7930 - loss: 0.4925 - val_accuracy: 0.7156 - val_loss: 0.7905
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.7843 - loss: 0.5699 - val_accuracy: 0.7346 - val_loss: 0.7058
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 379ms/step - accuracy: 0.8192 - loss: 0.4779 - val_accuracy: 0.6398 - val_loss: 0.8509
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.7557 - loss: 0.6162 - val_accuracy: 0.7156 - val_loss: 0.6757
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 383ms/step - accuracy: 0.8116 - loss: 0.4639 - val_accuracy: 0.7773 - val_loss: 0.5924
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 281ms/step - accuracy: 0.8212 - loss: 0.4442 - val_accuracy: 0.7820 - val_loss: 0.6138
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 345ms/step - accuracy: 0.8366 - loss: 0.4102 - val_accuracy: 0.7867 - val_loss: 0.5811
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - accuracy: 0.8670 - loss: 0.3928 - val_accuracy: 0.7251 - val_loss: 0.6143
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.8143 - loss: 0.4508 - val_accuracy: 0.6967 - val_loss: 0.8400
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.8279 - loss: 0.4405 - val_accuracy: 0.8152 - val_loss: 0.5327
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 331ms/step - accuracy: 0.8673 - loss: 0.3932 - val_accuracy: 0.8104 - val_loss: 0.5494
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.8716 - loss: 0.3650 - val_accuracy: 0.7962 - val_loss: 0.5571
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 359ms/step - accuracy: 0.8682 - loss: 0.3786 - val_accuracy: 0.8009 - val_loss: 0.5467
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.8422 - loss: 0.4168 - val_accuracy: 0.8009 - val_loss: 0.5928
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.8345 - loss: 0.4239 - val_accuracy: 0.7915 - val_loss: 0.6100
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 401ms/step - accuracy: 0.8371 - loss: 0.4213 - val_accuracy: 0.7773 - val_loss: 0.6096
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.8356 - loss: 0.4087 - val_accuracy: 0.8009 - val_loss: 0.5495
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 295ms/step - accuracy: 0.8572 - loss: 0.3807 - val_accuracy: 0.8152 - val_loss: 0.5242
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 381ms/step - accuracy: 0.8815 - loss: 0.3371 - val_accuracy: 0.8389 - val_loss: 0.4852
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.8759 - loss: 0.3347 - val_accuracy: 0.7725 - val_loss: 0.5589
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 383ms/step - accuracy: 0.8627 - loss: 0.3426 - val_accuracy: 0.7773 - val_loss: 0.6445
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 285ms/step - accuracy: 0.8275 - loss: 0.4325 - val_accuracy: 0.7062 - val_loss: 0.7119
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.8308 - loss: 0.4059 - val_accuracy: 0.7630 - val_loss: 0.6052
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - accuracy: 0.8298 - loss: 0.3850 - val_accuracy: 0.8246 - val_loss: 0.5093
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.8211 - loss: 0.4201 - val_accuracy: 0.7820 - val_loss: 0.5490
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.8740 - loss: 0.3449 - val_accuracy: 0.7820 - val_loss: 0.6235
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.8530 - loss: 0.3785 - val_accuracy: 0.8057 - val_loss: 0.5506
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 312ms/step - accuracy: 0.8868 - loss: 0.3299 - val_accuracy: 0.8009 - val_loss: 0.5304
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 381ms/step - accuracy: 0.9010 - loss: 0.2939 - val_accuracy: 0.8009 - val_loss: 0.5766

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import os

class_names = sorted(os.listdir(keypoints_dir))
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to one-hot encoded format if necessary
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Print classification report
print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Clothing       0.64      0.82      0.72        22
#        Dress       0.80      0.50      0.62        24
#          Hat       0.96      0.86      0.91        29
#         Pant       0.76      0.96      0.85        27
#       Pocket       0.73      0.83      0.78        23
#        Shirt       0.94      0.65      0.77        26
#        Shoes       1.00      0.81      0.89        26
#        Skirt       0.96      0.73      0.83        30
#         Suit       0.77      1.00      0.87        30
#      T-Shirt       0.76      0.96      0.85        27
#
#     accuracy                           0.82       264
#    macro avg       0.83      0.81      0.81       264
# weighted avg       0.84      0.82      0.81       264

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from google.colab import files

# Assuming 'keypoints_dir' contains subdirectories named after class labels
keypoints_dir = "/content/drive/MyDrive/keypoints"
class_names = sorted(os.listdir(keypoints_dir))

# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)  # Remove np.argmax if y_test is not one-hot encoded

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix and save it as an image
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Save the confusion matrix as an image
confusion_matrix_file = "confusion_matrix.png"
plt.savefig(confusion_matrix_file, dpi=300, bbox_inches='tight')
plt.show()

# Download the confusion matrix image
files.download(confusion_matrix_file)

# Generate and save the classification report
classification_report_text = classification_report(y_true_classes, y_pred_classes, target_names=class_names)

# Save the classification report as a text file
classification_report_file = "classification_report.txt"
with open(classification_report_file, "w") as f:
    f.write("Classification Report\n")
    f.write("=" * 80 + "\n\n")
    f.write(classification_report_text)

# Download the classification report text file
files.download(classification_report_file)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step

# %%
files.download(confusion_matrix_file)

# %%
 history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=32
    )
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 363ms/step - accuracy: 0.2185 - loss: 1.9980 - val_accuracy: 0.2133 - val_loss: 1.9405
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.2783 - loss: 1.9100 - val_accuracy: 0.1611 - val_loss: 2.0332
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.2212 - loss: 1.9974 - val_accuracy: 0.3649 - val_loss: 1.9375
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.2878 - loss: 1.8894 - val_accuracy: 0.3412 - val_loss: 1.9741
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.3420 - loss: 1.8819 - val_accuracy: 0.3318 - val_loss: 1.7535
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.3333 - loss: 1.7358 - val_accuracy: 0.3033 - val_loss: 1.7430
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 351ms/step - accuracy: 0.3080 - loss: 1.6601 - val_accuracy: 0.3602 - val_loss: 1.6174
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.3396 - loss: 1.6057 - val_accuracy: 0.2891 - val_loss: 1.6576
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 371ms/step - accuracy: 0.3303 - loss: 1.6083 - val_accuracy: 0.3744 - val_loss: 1.4931
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.4018 - loss: 1.4891 - val_accuracy: 0.3555 - val_loss: 1.5288
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 299ms/step - accuracy: 0.3966 - loss: 1.3979 - val_accuracy: 0.4265 - val_loss: 1.4359
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 368ms/step - accuracy: 0.4123 - loss: 1.3926 - val_accuracy: 0.3649 - val_loss: 1.4936
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.3946 - loss: 1.4016 - val_accuracy: 0.4360 - val_loss: 1.4240
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.4209 - loss: 1.4814 - val_accuracy: 0.4028 - val_loss: 1.3794
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 378ms/step - accuracy: 0.4405 - loss: 1.3358 - val_accuracy: 0.3934 - val_loss: 1.4058
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 299ms/step - accuracy: 0.4329 - loss: 1.3355 - val_accuracy: 0.4360 - val_loss: 1.3538
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.4531 - loss: 1.3275 - val_accuracy: 0.4313 - val_loss: 1.3605
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.4595 - loss: 1.2898 - val_accuracy: 0.3791 - val_loss: 1.3241
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step - accuracy: 0.5267 - loss: 1.2353 - val_accuracy: 0.4692 - val_loss: 1.2902
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.5039 - loss: 1.2327 - val_accuracy: 0.4123 - val_loss: 1.2716
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 349ms/step - accuracy: 0.5277 - loss: 1.1859 - val_accuracy: 0.4408 - val_loss: 1.2639
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 363ms/step - accuracy: 0.5101 - loss: 1.1790 - val_accuracy: 0.4882 - val_loss: 1.2304
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.5484 - loss: 1.1532 - val_accuracy: 0.5355 - val_loss: 1.2131
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.5461 - loss: 1.1340 - val_accuracy: 0.4929 - val_loss: 1.2135
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.5527 - loss: 1.1223 - val_accuracy: 0.5261 - val_loss: 1.1502
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.5759 - loss: 1.0660 - val_accuracy: 0.5450 - val_loss: 1.1808
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 381ms/step - accuracy: 0.5394 - loss: 1.1042 - val_accuracy: 0.5308 - val_loss: 1.1894
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.5644 - loss: 1.0861 - val_accuracy: 0.5403 - val_loss: 1.1762
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.5377 - loss: 1.0987 - val_accuracy: 0.5308 - val_loss: 1.1192
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 372ms/step - accuracy: 0.5831 - loss: 1.0275 - val_accuracy: 0.6019 - val_loss: 1.0825
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 319ms/step - accuracy: 0.6180 - loss: 1.0166 - val_accuracy: 0.5735 - val_loss: 1.1016
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.5921 - loss: 1.0040 - val_accuracy: 0.5640 - val_loss: 1.0411
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 348ms/step - accuracy: 0.6154 - loss: 0.9995 - val_accuracy: 0.5640 - val_loss: 1.1395
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - accuracy: 0.6207 - loss: 0.9664 - val_accuracy: 0.5308 - val_loss: 1.1408
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.6183 - loss: 0.9609 - val_accuracy: 0.5782 - val_loss: 1.0240
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.6515 - loss: 0.9036 - val_accuracy: 0.6114 - val_loss: 0.9905
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 337ms/step - accuracy: 0.6422 - loss: 0.9039 - val_accuracy: 0.5972 - val_loss: 1.0310
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.6677 - loss: 0.8943 - val_accuracy: 0.5782 - val_loss: 0.9971
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 353ms/step - accuracy: 0.6785 - loss: 0.8740 - val_accuracy: 0.5071 - val_loss: 1.0529
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.6267 - loss: 0.9240 - val_accuracy: 0.6019 - val_loss: 0.9610
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.6665 - loss: 0.8626 - val_accuracy: 0.5924 - val_loss: 0.9839
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 334ms/step - accuracy: 0.6767 - loss: 0.8611 - val_accuracy: 0.5308 - val_loss: 1.0265
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.5617 - loss: 1.0221 - val_accuracy: 0.4455 - val_loss: 1.3548
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step - accuracy: 0.5882 - loss: 1.0291 - val_accuracy: 0.6445 - val_loss: 0.9619
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 343ms/step - accuracy: 0.6581 - loss: 0.8465 - val_accuracy: 0.6351 - val_loss: 0.9255
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 330ms/step - accuracy: 0.6055 - loss: 0.9176 - val_accuracy: 0.5355 - val_loss: 1.0731
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.6204 - loss: 0.9048 - val_accuracy: 0.5498 - val_loss: 1.0074
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 338ms/step - accuracy: 0.6249 - loss: 0.9057 - val_accuracy: 0.6114 - val_loss: 0.9613
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 414ms/step - accuracy: 0.7163 - loss: 0.7974 - val_accuracy: 0.5735 - val_loss: 0.9281
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 348ms/step - accuracy: 0.6793 - loss: 0.8183 - val_accuracy: 0.5829 - val_loss: 1.1053
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - accuracy: 0.6551 - loss: 0.8600 - val_accuracy: 0.6493 - val_loss: 0.9014
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.7151 - loss: 0.7637 - val_accuracy: 0.6066 - val_loss: 0.9351
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 350ms/step - accuracy: 0.6870 - loss: 0.7833 - val_accuracy: 0.6398 - val_loss: 0.8880
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - accuracy: 0.7021 - loss: 0.7563 - val_accuracy: 0.6066 - val_loss: 1.0203
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.6778 - loss: 0.7948 - val_accuracy: 0.5024 - val_loss: 1.0446
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 374ms/step - accuracy: 0.6934 - loss: 0.7782 - val_accuracy: 0.6493 - val_loss: 0.8813
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.7193 - loss: 0.7199 - val_accuracy: 0.6114 - val_loss: 0.8802
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 374ms/step - accuracy: 0.7224 - loss: 0.7050 - val_accuracy: 0.6303 - val_loss: 0.8924
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - accuracy: 0.7045 - loss: 0.7393 - val_accuracy: 0.6114 - val_loss: 0.8793
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.7163 - loss: 0.7390 - val_accuracy: 0.6066 - val_loss: 0.8856
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 351ms/step - accuracy: 0.6948 - loss: 0.7738 - val_accuracy: 0.6493 - val_loss: 0.8876
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - accuracy: 0.7090 - loss: 0.7048 - val_accuracy: 0.6066 - val_loss: 0.8834
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 288ms/step - accuracy: 0.6685 - loss: 0.7630 - val_accuracy: 0.6398 - val_loss: 0.8801
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 352ms/step - accuracy: 0.7033 - loss: 0.7454 - val_accuracy: 0.6825 - val_loss: 0.8085
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.7557 - loss: 0.6560 - val_accuracy: 0.6019 - val_loss: 0.9286
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.7169 - loss: 0.7050 - val_accuracy: 0.6825 - val_loss: 0.8327
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 339ms/step - accuracy: 0.6686 - loss: 0.7734 - val_accuracy: 0.6493 - val_loss: 0.8236
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 377ms/step - accuracy: 0.7707 - loss: 0.6402 - val_accuracy: 0.6445 - val_loss: 0.8255
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 287ms/step - accuracy: 0.7152 - loss: 0.6831 - val_accuracy: 0.6682 - val_loss: 0.8049
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 351ms/step - accuracy: 0.6968 - loss: 0.7511 - val_accuracy: 0.6066 - val_loss: 0.9573
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 347ms/step - accuracy: 0.7057 - loss: 0.7548 - val_accuracy: 0.5592 - val_loss: 0.9948
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.7027 - loss: 0.7232 - val_accuracy: 0.6682 - val_loss: 0.8742
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 387ms/step - accuracy: 0.7197 - loss: 0.6678 - val_accuracy: 0.7014 - val_loss: 0.7809
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 298ms/step - accuracy: 0.7160 - loss: 0.6804 - val_accuracy: 0.6445 - val_loss: 0.8002
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 385ms/step - accuracy: 0.7051 - loss: 0.7113 - val_accuracy: 0.6777 - val_loss: 0.7640
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 285ms/step - accuracy: 0.7666 - loss: 0.6182 - val_accuracy: 0.7014 - val_loss: 0.7357
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 349ms/step - accuracy: 0.7655 - loss: 0.6038 - val_accuracy: 0.6682 - val_loss: 0.7740
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 424ms/step - accuracy: 0.7674 - loss: 0.6009 - val_accuracy: 0.7156 - val_loss: 0.7389
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 363ms/step - accuracy: 0.7746 - loss: 0.5894 - val_accuracy: 0.7109 - val_loss: 0.7453
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - accuracy: 0.7831 - loss: 0.5589 - val_accuracy: 0.6682 - val_loss: 0.7967
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.7115 - loss: 0.6900 - val_accuracy: 0.6161 - val_loss: 0.8317
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 378ms/step - accuracy: 0.7670 - loss: 0.6195 - val_accuracy: 0.6635 - val_loss: 0.7933
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.7444 - loss: 0.6207 - val_accuracy: 0.7393 - val_loss: 0.7071
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 324ms/step - accuracy: 0.7794 - loss: 0.5664 - val_accuracy: 0.7773 - val_loss: 0.6902
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 410ms/step - accuracy: 0.7632 - loss: 0.5900 - val_accuracy: 0.7251 - val_loss: 0.8272
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 17s 290ms/step - accuracy: 0.7411 - loss: 0.6407 - val_accuracy: 0.6967 - val_loss: 0.7032
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.7860 - loss: 0.5683 - val_accuracy: 0.7062 - val_loss: 0.7128
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 291ms/step - accuracy: 0.8159 - loss: 0.5150 - val_accuracy: 0.7678 - val_loss: 0.7123
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 297ms/step - accuracy: 0.8144 - loss: 0.4940 - val_accuracy: 0.7299 - val_loss: 0.7658
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 371ms/step - accuracy: 0.7701 - loss: 0.5838 - val_accuracy: 0.6919 - val_loss: 0.7990
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.7703 - loss: 0.5592 - val_accuracy: 0.6967 - val_loss: 0.6994
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 0.7820 - loss: 0.5580 - val_accuracy: 0.7251 - val_loss: 0.6894
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 382ms/step - accuracy: 0.7940 - loss: 0.5268 - val_accuracy: 0.7488 - val_loss: 0.6830
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.8297 - loss: 0.4980 - val_accuracy: 0.7393 - val_loss: 0.6512
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 390ms/step - accuracy: 0.8260 - loss: 0.4986 - val_accuracy: 0.7251 - val_loss: 0.7022
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 341ms/step - accuracy: 0.8062 - loss: 0.4944 - val_accuracy: 0.6967 - val_loss: 0.7025
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 388ms/step - accuracy: 0.8071 - loss: 0.5009 - val_accuracy: 0.7062 - val_loss: 0.7526
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 332ms/step - accuracy: 0.7179 - loss: 0.6489 - val_accuracy: 0.7441 - val_loss: 0.6569
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 394ms/step - accuracy: 0.8014 - loss: 0.4832 - val_accuracy: 0.7346 - val_loss: 0.6333
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 341ms/step - accuracy: 0.8443 - loss: 0.4705 - val_accuracy: 0.7441 - val_loss: 0.6928

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import os

class_names = sorted(os.listdir(keypoints_dir))
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to one-hot encoded format if necessary
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Print classification report
print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Clothing       0.64      0.32      0.42        22
#        Dress       0.53      0.79      0.63        24
#          Hat       0.97      0.97      0.97        29
#         Pant       0.76      0.96      0.85        27
#       Pocket       0.95      0.78      0.86        23
#        Shirt       0.85      0.65      0.74        26
#        Shoes       1.00      0.31      0.47        26
#        Skirt       1.00      0.70      0.82        30
#         Suit       0.83      1.00      0.91        30
#      T-Shirt       0.54      1.00      0.70        27
#
#     accuracy                           0.76       264
#    macro avg       0.81      0.75      0.74       264
# weighted avg       0.81      0.76      0.75       264

# %%
 history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=20,
        batch_size=32
    )
# Out:
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.9407 - loss: 0.1216 - val_accuracy: 0.8483 - val_loss: 0.4434
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 401ms/step - accuracy: 0.9655 - loss: 0.1187 - val_accuracy: 0.8863 - val_loss: 0.3806
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.9545 - loss: 0.1132 - val_accuracy: 0.8863 - val_loss: 0.3884
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 502ms/step - accuracy: 0.9561 - loss: 0.1055 - val_accuracy: 0.8673 - val_loss: 0.4382
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 400ms/step - accuracy: 0.9527 - loss: 0.1158 - val_accuracy: 0.8673 - val_loss: 0.3910
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 386ms/step - accuracy: 0.9662 - loss: 0.1046 - val_accuracy: 0.8341 - val_loss: 0.4916
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - accuracy: 0.8613 - loss: 0.3783 - val_accuracy: 0.7441 - val_loss: 0.9157
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 333ms/step - accuracy: 0.8735 - loss: 0.3150 - val_accuracy: 0.8104 - val_loss: 0.6077
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 402ms/step - accuracy: 0.9091 - loss: 0.2179 - val_accuracy: 0.7820 - val_loss: 0.6803
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 347ms/step - accuracy: 0.9266 - loss: 0.1906 - val_accuracy: 0.8863 - val_loss: 0.4454
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 394ms/step - accuracy: 0.9497 - loss: 0.1220 - val_accuracy: 0.8720 - val_loss: 0.3967
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - accuracy: 0.9566 - loss: 0.1119 - val_accuracy: 0.8815 - val_loss: 0.4104
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 289ms/step - accuracy: 0.9426 - loss: 0.1229 - val_accuracy: 0.8863 - val_loss: 0.4083
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 325ms/step - accuracy: 0.9648 - loss: 0.1026 - val_accuracy: 0.8768 - val_loss: 0.4026
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 397ms/step - accuracy: 0.9613 - loss: 0.1045 - val_accuracy: 0.8673 - val_loss: 0.3962
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.9455 - loss: 0.1252 - val_accuracy: 0.8815 - val_loss: 0.4208
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 392ms/step - accuracy: 0.9658 - loss: 0.0971 - val_accuracy: 0.8673 - val_loss: 0.4103
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 357ms/step - accuracy: 0.8949 - loss: 0.2790 - val_accuracy: 0.8199 - val_loss: 0.5168
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 0.9300 - loss: 0.1691 - val_accuracy: 0.8483 - val_loss: 0.4284
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - accuracy: 0.9493 - loss: 0.1279 - val_accuracy: 0.8626 - val_loss: 0.4116

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import os

class_names = sorted(os.listdir(keypoints_dir))
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to one-hot encoded format if necessary
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Print classification report
print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     Clothing       0.71      0.91      0.80        22
#        Dress       0.78      0.58      0.67        24
#          Hat       1.00      0.97      0.98        29
#         Pant       0.84      0.96      0.90        27
#       Pocket       0.92      1.00      0.96        23
#        Shirt       0.83      0.92      0.87        26
#        Shoes       1.00      0.88      0.94        26
#        Skirt       0.96      0.80      0.87        30
#         Suit       0.93      0.93      0.93        30
#      T-Shirt       0.96      0.96      0.96        27
#
#     accuracy                           0.89       264
#    macro avg       0.89      0.89      0.89       264
# weighted avg       0.90      0.89      0.89       264

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from google.colab import files

# Assuming 'keypoints_dir' contains subdirectories named after class labels
keypoints_dir = "/content/drive/MyDrive/keypoints"
class_names = sorted(os.listdir(keypoints_dir))

# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predictions and true labels to class indices
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)  # Remove np.argmax if y_test is not one-hot encoded

# Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix and save it as an image
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Save the confusion matrix as an image
confusion_matrix_file = "confusion_matrix.png"
plt.savefig(confusion_matrix_file, dpi=300, bbox_inches='tight')
plt.show()

# Download the confusion matrix image
files.download(confusion_matrix_file)

# Generate and save the classification report
classification_report_text = classification_report(y_true_classes, y_pred_classes, target_names=class_names)

# Save the classification report as a text file
classification_report_file = "classification_report.txt"
with open(classification_report_file, "w") as f:
    f.write("Classification Report\n")
    f.write("=" * 80 + "\n\n")
    f.write(classification_report_text)

# Download the classification report text file
files.download(classification_report_file)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step

# %%
files.download(confusion_matrix_file)

# %%
import shutil
from google.colab import files

# Save the model in TensorFlow's SavedModel format
saved_model_dir = "video_classification_model"
model.export(saved_model_dir)

# Compress the directory for downloading
shutil.make_archive(saved_model_dir, 'zip', saved_model_dir)

# Download the compressed model
files.download(f"{saved_model_dir}.zip")
# Out:
# Saved artifact at 'video_classification_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 116, 1662), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   137337198084336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337191336592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337198098944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337191347152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337191337824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337191349968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137337191333952: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Save the model in HDF5 format
h5_model_file = "video_classification_model.h5"
model.save(h5_model_file)

# Download the model file
files.download(h5_model_file)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
